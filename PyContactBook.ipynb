# %%
contacts = []

while True:
    print("\n==== Contact Book ====")
    print("1. Add Contact")
    print("2. Search Contact")
    print("3. Delete Contact")
    print("4. Show All Contacts")
    print("5. Exit")
    choice = input("Choose an option (1-5): ")

    if choice == "1":
        name = input("Enter Name: ")
        phone = input("Enter Phone: ")
        email = input("Enter Email: ")
        if name and phone and email:
            contacts.append((name, phone, email))
            print("Contact added successfully!")
        else:
            print("Invalid input. All fields are required.")

    elif choice == "2":
        search_name = input("Enter name to search: ")
        found = False
        for contact in contacts:
            if contact[0].lower() == search_name.lower():
                print("Found:", contact)
                found = True
        if not found:
            print("Contact not found.")

    elif choice == "3":
        delete_name = input("Enter name to delete: ")
        deleted = False
        for contact in contacts:
            if contact[0].lower() == delete_name.lower():
                contacts.remove(contact)
                print("Contact deleted.")
                deleted = True
                break
        if not deleted:
            print("No contact found with that name.")

    elif choice == "4":
        if len(contacts) == 0:
            print("No contacts saved.")
        else:
            print("\n--- Contact List ---")
            for c in contacts:
                print("Name:", c[0], "| Phone:", c[1], "| Email:", c[2])

    elif choice == "5":
        print("Exiting... Thank you!")
        break

    else:
        print("Invalid option. Please choose between 1 to 5.")
# Out:
# ==== Contact Book ====
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Show All Contacts
# 5. Exit
# Contact added successfully!
#
# ==== Contact Book ====
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Show All Contacts
# 5. Exit
# Contact added successfully!
#
# ==== Contact Book ====
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Show All Contacts
# 5. Exit
# Contact added successfully!
#
# ==== Contact Book ====
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Show All Contacts
# 5. Exit
# Found: ('TAHIR ALI', '0300-___________', 'tahirali@gmail.com')
#
# ==== Contact Book ====
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Show All Contacts
# 5. Exit
# No contact found with that name.
#
# ==== Contact Book ====
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Show All Contacts
# 5. Exit
#
# --- Contact List ---
# Name: AHMAD ALI  | Phone: 0349-___________ | Email: ahmadali@gmail.com
# Name: GILL KHAN | Phone: 0341-_________ | Email: gullkhan@gmail.com
# Name: TAHIR ALI | Phone: 0300-___________ | Email: tahirali@gmail.com
#
# ==== Contact Book ====
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Show All Contacts
# 5. Exit
# Exiting... Thank you!
